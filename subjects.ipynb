# %%
# ----------------------------------------------
# Able‑bodied adult subject metadata (all subjects together)
# ----------------------------------------------

able_bodied_subjects = [
    # Subject ID, Age, Sex, Weight (kg), Height (mm), Leg Length (mm),
    # Left walking speed (m/s), Right walking speed (m/s)
    {"id": "SUBJ1",  "age": 86, "sex": "M",  "weight_kg": 64,  "height_mm": 1580, "leg_length_mm": 850,
     "left_speed_mps": 1.0544, "right_speed_mps": 1.0673},
    {"id": "SUBJ2",  "age": 85, "sex": "F",  "weight_kg": 78,  "height_mm": 1500, "leg_length_mm": 840,
     "left_speed_mps": 0.9095, "right_speed_mps": 0.9064},
    {"id": "SUBJ3",  "age": 85, "sex": "F",  "weight_kg": 69,  "height_mm": 1510, "leg_length_mm": 880,
     "left_speed_mps": 0.8799, "right_speed_mps": 0.8798},
    {"id": "SUBJ4",  "age": 84, "sex": "M",  "weight_kg": 70,  "height_mm": 1625, "leg_length_mm": 950,
     "left_speed_mps": 1.0838, "right_speed_mps": 1.0883},
    {"id": "SUBJ5",  "age": 84, "sex": "F",  "weight_kg": 50,  "height_mm": 1450, "leg_length_mm": 810,
     "left_speed_mps": 0.8014, "right_speed_mps": 0.8042},
    {"id": "SUBJ6",  "age": 83, "sex": "M",  "weight_kg": 80,  "height_mm": 1695, "leg_length_mm": 970,
     "left_speed_mps": 1.3000, "right_speed_mps": 1.2975},
    {"id": "SUBJ7",  "age": 82, "sex": "F",  "weight_kg": 62,  "height_mm": 1555, "leg_length_mm": 840,
     "left_speed_mps": 1.1607, "right_speed_mps": 1.1611},
    {"id": "SUBJ8",  "age": 82, "sex": "F",  "weight_kg": 72,  "height_mm": 1600, "leg_length_mm": 820,
     "left_speed_mps": 1.1534, "right_speed_mps": 1.1599},
    {"id": "SUBJ9",  "age": 82, "sex": "M",  "weight_kg": 87,  "height_mm": 1710, "leg_length_mm": 920,
     "left_speed_mps": 1.0958, "right_speed_mps": 1.0977},
    {"id": "SUBJ10", "age": 81, "sex": "M",  "weight_kg": 73,  "height_mm": 1620, "leg_length_mm": 870,
     "left_speed_mps": 1.0689, "right_speed_mps": 1.0692},
    {"id": "SUBJ11", "age": 81, "sex": "M",  "weight_kg": 76,  "height_mm": 1700, "leg_length_mm": 910,
     "left_speed_mps": 1.1414, "right_speed_mps": 1.1333},
    {"id": "SUBJ12", "age": 80, "sex": "M",  "weight_kg": 101, "height_mm": 1890, "leg_length_mm":1070,
     "left_speed_mps": 1.1529, "right_speed_mps": 1.1274},
    {"id": "SUBJ13", "age": 80, "sex": "F",  "weight_kg": 70,  "height_mm": 1540, "leg_length_mm": 870,
     "left_speed_mps": 1.0539, "right_speed_mps": 1.0516},
    {"id": "SUBJ14", "age": 80, "sex": "M",  "weight_kg": 87,  "height_mm": 1755, "leg_length_mm": 920,
     "left_speed_mps": 1.1406, "right_speed_mps": 1.1771},
    {"id": "SUBJ15", "age": 83, "sex": "F",  "weight_kg": 74,  "height_mm": 1530, "leg_length_mm": 820,
     "left_speed_mps": 1.0336, "right_speed_mps": 1.0355},
    {"id": "SUBJ16", "age": 79, "sex": "F",  "weight_kg": 74,  "height_mm": 1610, "leg_length_mm": 860,
     "left_speed_mps": 1.1737, "right_speed_mps": 1.1647},
    {"id": "SUBJ17", "age": 77, "sex": "M",  "weight_kg": 86,  "height_mm": 1750, "leg_length_mm": 950,
     "left_speed_mps": 1.1015, "right_speed_mps": 1.1231},
    {"id": "SUBJ18", "age": 77, "sex": "M",  "weight_kg": 90,  "height_mm": 1770, "leg_length_mm": 940,
     "left_speed_mps": 1.1414, "right_speed_mps": 1.1222},
    {"id": "SUBJ19", "age": 77, "sex": "M",  "weight_kg": 88,  "height_mm": 1830, "leg_length_mm":1030,
     "left_speed_mps": 1.0232, "right_speed_mps": 1.0165},
    {"id": "SUBJ20", "age": 76, "sex": "M",  "weight_kg": 79,  "height_mm": 1750, "leg_length_mm":970,
     "left_speed_mps": 0.9628, "right_speed_mps": 0.9566},
    {"id": "SUBJ21", "age": 75, "sex": "F",  "weight_kg": 78,  "height_mm": 1420, "leg_length_mm":660,
     "left_speed_mps": 1.0706, "right_speed_mps": 1.0692},
    {"id": "SUBJ22", "age": 79, "sex": "M",  "weight_kg": 83,  "height_mm": 1645, "leg_length_mm":898,
     "left_speed_mps": 0.9814, "right_speed_mps": 0.9755},
    {"id": "SUBJ23", "age": 75, "sex": "M",  "weight_kg": 89,  "height_mm": 1665, "leg_length_mm":880,
     "left_speed_mps": 1.0184, "right_speed_mps": 1.0051},
    {"id": "SUBJ24", "age": 74, "sex": "F",  "weight_kg": 72,  "height_mm": 1585, "leg_length_mm":850,
     "left_speed_mps": 1.1847, "right_speed_mps": 1.1753},
    {"id": "SUBJ25", "age": 74, "sex": "F",  "weight_kg": 83,  "height_mm": 1545, "leg_length_mm":810,
     "left_speed_mps": 1.1467, "right_speed_mps": 1.1373},
    {"id": "SUBJ26", "age": 73, "sex": "F",  "weight_kg": 64,  "height_mm": 1605, "leg_length_mm":860,
     "left_speed_mps": 1.2963, "right_speed_mps": 1.2944},
    {"id": "SUBJ27", "age": 73, "sex": "F",  "weight_kg": 61,  "height_mm": 1595, "leg_length_mm":870,
     "left_speed_mps": 0.8338, "right_speed_mps": 0.8148},
    {"id": "SUBJ28", "age": 72, "sex": "F",  "weight_kg": 69,  "height_mm": 1605, "leg_length_mm":860,
     "left_speed_mps": 1.0919, "right_speed_mps": 1.1002},
    {"id": "SUBJ29", "age": 72, "sex": "F",  "weight_kg": 75,  "height_mm": 1560, "leg_length_mm":880,
     "left_speed_mps": 1.2268, "right_speed_mps": 1.2117},
    {"id": "SUBJ30", "age": 72, "sex": "F",  "weight_kg": 61,  "height_mm": 1585, "leg_length_mm":870,
     "left_speed_mps": 1.4127, "right_speed_mps": 1.4188},
    {"id": "SUBJ31", "age": 71, "sex": "M",  "weight_kg": 65,  "height_mm": 1610, "leg_length_mm":830,
     "left_speed_mps": 1.3850, "right_speed_mps": 1.3964},
    {"id": "SUBJ32", "age": 71, "sex": "M",  "weight_kg": 83,  "height_mm": 1725, "leg_length_mm":950,
     "left_speed_mps": 1.0652, "right_speed_mps": 1.0638},
    {"id": "SUBJ33", "age": 70, "sex": "M",  "weight_kg": 82,  "height_mm": 1795, "leg_length_mm":995,
     "left_speed_mps": 1.4247, "right_speed_mps": 1.4405},
    {"id": "SUBJ34", "age": 69, "sex": "M",  "weight_kg": 76,  "height_mm": 1655, "leg_length_mm":890,
     "left_speed_mps": 1.1887, "right_speed_mps": 1.1964},
    {"id": "SUBJ35", "age": 67, "sex": "M",  "weight_kg": 92,  "height_mm": 1830, "leg_length_mm":970,
     "left_speed_mps": 1.3170, "right_speed_mps": 1.3316},
    {"id": "SUBJ36", "age": 67, "sex": "M",  "weight_kg": 74,  "height_mm": 1690, "leg_length_mm":930,
     "left_speed_mps": 1.1359, "right_speed_mps": 1.1420},
    {"id": "SUBJ37", "age": 66, "sex": "F",  "weight_kg": 55,  "height_mm": 1615, "leg_length_mm":860,
     "left_speed_mps": 1.2498, "right_speed_mps": 1.2636},
    {"id": "SUBJ38", "age": 66, "sex": "F",  "weight_kg": 57,  "height_mm": 1635, "leg_length_mm":870,
     "left_speed_mps": 1.1878, "right_speed_mps": 1.2056},
    {"id": "SUBJ39", "age": 65, "sex": "F",  "weight_kg": 69,  "height_mm": 1645, "leg_length_mm":890,
     "left_speed_mps": 1.0483, "right_speed_mps": 1.0454},
    {"id": "SUBJ40", "age": 65, "sex": "M",  "weight_kg": 95,  "height_mm": 1750, "leg_length_mm":930,
     "left_speed_mps": 1.1896, "right_speed_mps": 1.1770},
    {"id": "SUBJ41", "age": 64, "sex": "F",  "weight_kg": 75,  "height_mm": 1580, "leg_length_mm":900,
     "left_speed_mps": 1.2724, "right_speed_mps": 1.2630},
    {"id": "SUBJ42", "age": 64, "sex": "F",  "weight_kg": 82,  "height_mm": 1550, "leg_length_mm":840,
     "left_speed_mps": 0.9759, "right_speed_mps": 0.9685},
    {"id": "SUBJ43", "age": 62, "sex": "M",  "weight_kg": 95,  "height_mm": 1770, "leg_length_mm":960,
     "left_speed_mps": 1.4288, "right_speed_mps": 1.4206},
    {"id": "SUBJ44", "age": 62, "sex": "F",  "weight_kg": 80,  "height_mm": 1565, "leg_length_mm":860,
     "left_speed_mps": 1.1456, "right_speed_mps": 1.1369},
    {"id": "SUBJ45", "age": 61, "sex": "F",  "weight_kg": 79,  "height_mm": 1615, "leg_length_mm":880,
     "left_speed_mps": 1.4189, "right_speed_mps": 1.1727},
    {"id": "SUBJ46", "age": 60, "sex": "F",  "weight_kg": 66,  "height_mm": 1580, "leg_length_mm":860,
     "left_speed_mps": 1.2879, "right_speed_mps": 1.2732},
    {"id": "SUBJ47", "age": 60, "sex": "M",  "weight_kg": 69,  "height_mm": 1710, "leg_length_mm":960,
     "left_speed_mps": 1.1791, "right_speed_mps": 1.1666},
    {"id": "SUBJ48", "age": 60, "sex": "M",  "weight_kg": 59,  "height_mm": 1740, "leg_length_mm":880,
     "left_speed_mps": 1.0946, "right_speed_mps": 1.1065},
    {"id": "SUBJ49", "age": 60, "sex": "F",  "weight_kg": 85,  "height_mm": 1645, "leg_length_mm":910,
     "left_speed_mps": 1.0942, "right_speed_mps": 1.0986},
    {"id": "SUBJ50", "age": 59, "sex": "F",  "weight_kg": 62,  "height_mm": 1515, "leg_length_mm":800,
     "left_speed_mps": 0.9895, "right_speed_mps": 1.0005},
    {"id": "SUBJ51", "age": 59, "sex": "F",  "weight_kg": 64,  "height_mm": 1660, "leg_length_mm":870,
     "left_speed_mps": 1.4176, "right_speed_mps": 1.4258},
    {"id": "SUBJ52", "age": 58, "sex": "F",  "weight_kg": 61,  "height_mm": 1595, "leg_length_mm":860,
     "left_speed_mps": 1.0400, "right_speed_mps": 1.0342},
    {"id": "SUBJ53", "age": 58, "sex": "M",  "weight_kg": 79,  "height_mm": 1715, "leg_length_mm":920,
     "left_speed_mps": 1.5175, "right_speed_mps": 1.5686},
    {"id": "SUBJ54", "age": 57, "sex": "F",  "weight_kg": 58,  "height_mm": 1640, "leg_length_mm":870,
     "left_speed_mps": 1.4960, "right_speed_mps": 1.4728},
    {"id": "SUBJ55", "age": 57, "sex": "F",  "weight_kg": 62,  "height_mm": 1580, "leg_length_mm":870,
     "left_speed_mps": 1.0492, "right_speed_mps": 1.0430},
    {"id": "SUBJ56", "age": 55, "sex": "F",  "weight_kg": 58,  "height_mm": 1635, "leg_length_mm":820,
     "left_speed_mps": 1.4704, "right_speed_mps": 1.4694},
    {"id": "SUBJ57", "age": 55, "sex": "M",  "weight_kg": 67,  "height_mm": 1685, "leg_length_mm":880,
     "left_speed_mps": 1.2729, "right_speed_mps": 1.2610},
    {"id": "SUBJ58", "age": 55, "sex": "M",  "weight_kg": 66,  "height_mm": 1795, "leg_length_mm":930,
     "left_speed_mps": 1.4857, "right_speed_mps": 1.4417},
    {"id": "SUBJ59", "age": 54, "sex": "F",  "weight_kg": 57,  "height_mm": 1675, "leg_length_mm":860,
     "left_speed_mps": 1.0593, "right_speed_mps": 1.0792},
    {"id": "SUBJ60", "age": 53, "sex": "M",  "weight_kg": 90,  "height_mm": 1780, "leg_length_mm":940,
     "left_speed_mps": 1.5793, "right_speed_mps": 1.5703},
    {"id": "SUBJ61", "age": 53, "sex": "M",  "weight_kg": 89,  "height_mm": 1770, "leg_length_mm":960,
     "left_speed_mps": 1.0976, "right_speed_mps": 1.0999},
    {"id": "SUBJ62", "age": 53, "sex": "M",  "weight_kg": 69,  "height_mm": 1765, "leg_length_mm":900,
     "left_speed_mps": 1.0926, "right_speed_mps": 1.0959},
    {"id": "SUBJ63", "age": 53, "sex": "F",  "weight_kg": 72,  "height_mm": 1655, "leg_length_mm":880,
     "left_speed_mps": 1.5023, "right_speed_mps": 1.5244},
    {"id": "SUBJ64", "age": 52, "sex": "F",  "weight_kg": 53,  "height_mm": 1580, "leg_length_mm":830,
     "left_speed_mps": 1.3717, "right_speed_mps": 1.3784},
    {"id": "SUBJ65", "age": 52, "sex": "F",  "weight_kg": 62,  "height_mm": 1560, "leg_length_mm":840,
     "left_speed_mps": 1.2118, "right_speed_mps": 1.2375},
    {"id": "SUBJ66", "age": 55, "sex": "M",  "weight_kg": 86,  "height_mm": 1755, "leg_length_mm":910,
     "left_speed_mps": 1.0588, "right_speed_mps": 1.0521},
    {"id": "SUBJ67", "age": 55, "sex": "F",  "weight_kg": 48,  "height_mm": 1565, "leg_length_mm":831,
     "left_speed_mps": 1.1318, "right_speed_mps": 1.1214},
    {"id": "SUBJ68", "age": 51, "sex": "F",  "weight_kg": 57,  "height_mm": 1630, "leg_length_mm":840,
     "left_speed_mps": 1.5848, "right_speed_mps": 1.5924},
    {"id": "SUBJ69", "age": 50, "sex": "F",  "weight_kg": 51,  "height_mm": 1685, "leg_length_mm":890,
     "left_speed_mps": 1.3298, "right_speed_mps": 1.3346},
    {"id": "SUBJ70", "age": 54, "sex": "F",  "weight_kg": 67,  "height_mm": 1660, "leg_length_mm":890,
     "left_speed_mps": 1.1738, "right_speed_mps": 1.1708},
    {"id": "SUBJ71", "age": 50, "sex": "M",  "weight_kg": 80,  "height_mm": 1885, "leg_length_mm":1050,
     "left_speed_mps": 1.3464, "right_speed_mps": 1.3442},
    {"id": "SUBJ72", "age": 49, "sex": "M",  "weight_kg": 81,  "height_mm": 1670, "leg_length_mm":860,
     "left_speed_mps": 1.2657, "right_speed_mps": 1.2659},
    {"id": "SUBJ73", "age": 49, "sex": "F",  "weight_kg": 69,  "height_mm": 1680, "leg_length_mm":900,
     "left_speed_mps": 1.1601, "right_speed_mps": 1.1635},
    {"id": "SUBJ74", "age": 49, "sex": "M",  "weight_kg": 80,  "height_mm": 1815, "leg_length_mm":950,
     "left_speed_mps": 1.2064, "right_speed_mps": 1.1911},
    {"id": "SUBJ75", "age": 48, "sex": "F",  "weight_kg": 67,  "height_mm": 1600, "leg_length_mm":860,
     "left_speed_mps": 1.0645, "right_speed_mps": 1.0592},
    {"id": "SUBJ76", "age": 48, "sex": "M",  "weight_kg": 97,  "height_mm": 1780, "leg_length_mm":960,
     "left_speed_mps": 1.1899, "right_speed_mps": 1.1888},
    {"id": "SUBJ77", "age": 48, "sex": "M",  "weight_kg": 80,  "height_mm": 1880, "leg_length_mm":990,
     "left_speed_mps": 1.1833, "right_speed_mps": 1.1780},
    {"id": "SUBJ78", "age": 51, "sex": "F",  "weight_kg": 64,  "height_mm": 1605, "leg_length_mm":870,
     "left_speed_mps": 1.1475, "right_speed_mps": 1.1550},
    {"id": "SUBJ79", "age": 46, "sex": "F",  "weight_kg": 48,  "height_mm": 1525, "leg_length_mm":800,
     "left_speed_mps": 1.1167, "right_speed_mps": 1.1107},
    {"id": "SUBJ80", "age": 50, "sex": "M",  "weight_kg": 72,  "height_mm": 1730, "leg_length_mm":875,
     "left_speed_mps": 1.6058, "right_speed_mps": 1.5733},
    {"id": "SUBJ81", "age": 45, "sex": "M",  "weight_kg": 77,  "height_mm": 1750, "leg_length_mm":930,
     "left_speed_mps": 1.1529, "right_speed_mps": 1.1411},
    {"id": "SUBJ82", "age": 45, "sex": "F",  "weight_kg": 70,  "height_mm": 1915, "leg_length_mm":830,
     "left_speed_mps": 1.5416, "right_speed_mps": 1.5244},
    {"id": "SUBJ83", "age": 44, "sex": "F",  "weight_kg": 55,  "height_mm": 1475, "leg_length_mm":760,
     "left_speed_mps": 1.3231, "right_speed_mps": 1.3236},
    {"id": "SUBJ84", "age": 44, "sex": "F",  "weight_kg": 70,  "height_mm": 1585, "leg_length_mm":850,
     "left_speed_mps": 1.1323, "right_speed_mps": 1.1394},
    {"id": "SUBJ85", "age": 44, "sex": "M",  "weight_kg": 79,  "height_mm": 1675, "leg_length_mm":910,
     "left_speed_mps": 1.1910, "right_speed_mps": 1.1847},
    {"id": "SUBJ86", "age": 44, "sex": "F",  "weight_kg": 81,  "height_mm": 1655, "leg_length_mm":880,
     "left_speed_mps": 1.4056, "right_speed_mps": 1.4060},
    {"id": "SUBJ87", "age": 44, "sex": "M",  "weight_kg":100,  "height_mm": 1775, "leg_length_mm":950,
     "left_speed_mps": 1.2190, "right_speed_mps": 1.2071},
    {"id": "SUBJ88", "age": 44, "sex": "F",  "weight_kg": 94,  "height_mm": 1750, "leg_length_mm":930,
     "left_speed_mps": 1.2002, "right_speed_mps": 1.1990},
    {"id": "SUBJ89", "age": 43, "sex": "M",  "weight_kg": 74,  "height_mm": 1755, "leg_length_mm":950,
     "left_speed_mps": 1.4343, "right_speed_mps": 1.4424},
    {"id": "SUBJ90", "age": 42, "sex": "F",  "weight_kg": 50,  "height_mm": 1535, "leg_length_mm":780,
     "left_speed_mps": 1.0378, "right_speed_mps": 1.0315},
    {"id": "SUBJ91", "age": 41, "sex": "F",  "weight_kg": 58,  "height_mm": 1535, "leg_length_mm":800,
     "left_speed_mps": 1.3774, "right_speed_mps": 1.3507},
    {"id": "SUBJ92", "age": 40, "sex": "F",  "weight_kg":109,  "height_mm": 1720, "leg_length_mm":880,
     "left_speed_mps": 1.1933, "right_speed_mps": 1.1812},
    {"id": "SUBJ93", "age": 39, "sex": "F",  "weight_kg": 73,  "height_mm": 1665, "leg_length_mm":900,
     "left_speed_mps": 1.1691, "right_speed_mps": 1.1625},
    {"id": "SUBJ94", "age": 42, "sex": "M",  "weight_kg": 79,  "height_mm": 1725, "leg_length_mm":935,
     "left_speed_mps": 1.1644, "right_speed_mps": 1.1652},
    {"id": "SUBJ95", "age": 37, "sex": "M",  "weight_kg":103,  "height_mm": 1920, "leg_length_mm":1020,
     "left_speed_mps": 1.2634, "right_speed_mps": 1.2757},
    {"id": "SUBJ96", "age": 36, "sex": "M",  "weight_kg":157,  "height_mm": 1830, "leg_length_mm":950,
     "left_speed_mps": 1.2023, "right_speed_mps": 1.2225},
    {"id": "SUBJ97", "age": 36, "sex": "M",  "weight_kg": 65,  "height_mm": 1735, "leg_length_mm":950,
     "left_speed_mps": 1.3344, "right_speed_mps": 1.3416},
    {"id": "SUBJ98", "age": 36, "sex": "M",  "weight_kg": 76,  "height_mm": 1765, "leg_length_mm":970,
     "left_speed_mps": 1.1551, "right_speed_mps": 1.1645},
    {"id": "SUBJ99", "age": 34, "sex": "F",  "weight_kg": 62,  "height_mm": 1700, "leg_length_mm":940,
     "left_speed_mps": 1.3088, "right_speed_mps": 1.2992},
    {"id": "SUBJ100","age":34,"sex":"M","weight_kg":78,"height_mm":1820,"leg_length_mm":980,
     "left_speed_mps":1.3257,"right_speed_mps":1.3232},
    {"id": "SUBJ101","age":34,"sex":"F","weight_kg":60,"height_mm":1715,"leg_length_mm":900,
     "left_speed_mps":1.2982,"right_speed_mps":1.2988},
    {"id": "SUBJ102","age":33,"sex":"F","weight_kg":59,"height_mm":1575,"leg_length_mm":830,
     "left_speed_mps":1.0499,"right_speed_mps":1.0534},
    {"id": "SUBJ103","age":33,"sex":"F","weight_kg":70,"height_mm":1605,"leg_length_mm":890,
     "left_speed_mps":1.0001,"right_speed_mps":1.0064},
    {"id": "SUBJ104","age":32,"sex":"F","weight_kg":71,"height_mm":1645,"leg_length_mm":890,
     "left_speed_mps":1.4896,"right_speed_mps":1.4750},
    {"id": "SUBJ105","age":31,"sex":"F","weight_kg":58,"height_mm":1675,"leg_length_mm":880,
     "left_speed_mps":0.9778,"right_speed_mps":0.9783},
    {"id": "SUBJ106","age":30,"sex":"F","weight_kg":65,"height_mm":1670,"leg_length_mm":870,
     "left_speed_mps":1.2414,"right_speed_mps":1.2354}
]

# %%
# Sort by leg/height ratio (ascending order)
able_bodied_subjects.sort(key=lambda subj: subj["leg_length_mm"] / subj["height_mm"])
# print subject ids and leg/height ratio in ascending order
for subj in able_bodied_subjects:
    leg_height_ratio = subj["leg_length_mm"] / subj["height_mm"]
    print(f"{subj['id']}: Leg/Height Ratio = {leg_height_ratio:.3f}")
# Out:
# SUBJ82: Leg/Height Ratio = 0.433
# SUBJ21: Leg/Height Ratio = 0.465
# SUBJ56: Leg/Height Ratio = 0.502
# SUBJ48: Leg/Height Ratio = 0.506
# SUBJ80: Leg/Height Ratio = 0.506
# SUBJ90: Leg/Height Ratio = 0.508
# SUBJ62: Leg/Height Ratio = 0.510
# SUBJ92: Leg/Height Ratio = 0.512
# SUBJ8: Leg/Height Ratio = 0.512
# SUBJ59: Leg/Height Ratio = 0.513
# SUBJ72: Leg/Height Ratio = 0.515
# SUBJ83: Leg/Height Ratio = 0.515
# SUBJ68: Leg/Height Ratio = 0.515
# SUBJ31: Leg/Height Ratio = 0.516
# SUBJ58: Leg/Height Ratio = 0.518
# SUBJ66: Leg/Height Ratio = 0.519
# SUBJ96: Leg/Height Ratio = 0.519
# SUBJ106: Leg/Height Ratio = 0.521
# SUBJ91: Leg/Height Ratio = 0.521
# SUBJ57: Leg/Height Ratio = 0.522
# SUBJ74: Leg/Height Ratio = 0.523
# SUBJ51: Leg/Height Ratio = 0.524
# SUBJ14: Leg/Height Ratio = 0.524
# SUBJ25: Leg/Height Ratio = 0.524
# SUBJ79: Leg/Height Ratio = 0.525
# SUBJ101: Leg/Height Ratio = 0.525
# SUBJ64: Leg/Height Ratio = 0.525
# SUBJ105: Leg/Height Ratio = 0.525
# ...
